# %%
import pandas as pd
prefix="./output/emma"
artist_genre_df = pd.read_csv(f"{prefix}_artist_genre_info.csv")
artist_df = pd.read_csv(f"{prefix}_artist_info.csv")
song_df = pd.read_csv(f"{prefix}_song_info.csv")
album_counts = pd.read_csv(f"{prefix}_album_info.csv")

# %%
print(f"you listed to {len(artist_genre_df)} different genres in this time period! Here are the top 15")
artist_genre_df.head(15)
# Out:
# you listed to 498 different genres in this time period! Here are the top 15
#                 genre  count
# 0           indie pop     86
# 1          indie folk     83
# 2    stomp and holler     79
# 3          indie rock     69
# 4   singer-songwriter     68
# 5          pov: indie     66
# 6       new americana     65
# 7         chamber pop     60
# 8                folk     60
# 9                rock     58
# 10                pop     50
# 11        modern rock     48
# 12       classic rock     47
# 13        mellow gold     37
# 14            art pop     37

# %%
print(f"you listened to {len(artist_df)} artists in this time period!")
print(f"The average popularity of the artists you listen to is {artist_df['popularity'].mean()}. Here are the top 25")
artist_df.head(25)
# Out:
# you listened to 998 artists in this time period!
# The average popularity of the artists you listen to is 55.66032064128257. Here are the top 25
#                     artist  popularity  \
# 0            Maggie Rogers          71
# 1         Lake Street Dive          64
# 2              Miley Cyrus          84
# 3            First Aid Kit          62
# 4               Noah Kahan          86
# 5                 Lawrence          59
# 6                boygenius          68
# 7                The Beths          48
# 8          Phoebe Bridgers          80
# 9             Julien Baker          68
# 10    The Ballroom Thieves          50
# 11                   Caamp          70
# 12           The Lumineers          79
# 13          Brandi Carlile          65
# 14             girl in red          77
# 15  Florence + The Machine          78
# 16                 Ratboys          41
# 17            Taylor Swift         100
# 18         Vampire Weekend          67
# ...

# %%
print(f"you listened to {len(song_df)} songs in this time period!")
print(f"The average popularity of the songs you listen to is {song_df['popularity'].mean()}. Here are the top 25")
song_df.head(25)
# Out:
# you listened to 9221 songs in this time period!
# The average popularity of the songs you listen to is 37.73506127318078. Here are the top 25
#                         song  popularity  \
# 0              Cool About It          70
# 1   Without You Without Them          51
# 2              Graceland Too          64
# 3                  True Blue          62
# 4            Emily I'm Sorry          59
# 5          Not Strong Enough          72
# 6               Faith Healer          44
# 7      My Love Mine All Mine          88
# 8                 concussion          43
# 9            Don't Forget Me          54
# 10                  Hardline          39
# 11   Expert In A Dying Field          44
# 12                Anti-Curse          49
# 13                       $20          56
# 14               Ketchum, ID          51
# 15            Sprained Ankle          38
# 16                   Shatter          54
# 17             Leonard Cohen          53
# ...

# %%
print(f"you listened to {len(album_counts)} different albums this year!")
print("here are the top 20")
album_counts.head(20)
# Out:
# you listened to 5900 different albums this year!
# here are the top 20
#                                      album  \
# 0                               the record
# 1                                 Punisher
# 2                         Little Oblivions
# 3   The Land Is Inhospitable and So Are We
# 4                               concussion
# 5                          Don't Forget Me
# 6                  Expert In A Dying Field
# 7                                boygenius
# 8                           Sprained Ankle
# 9                                Surrender
# 10                                      GN
# 11                              The Window
# 12            I'm Wide Awake, It's Morning
# 13                  Lungs (Deluxe Edition)
# 14                                      26
# 15                            Stick Season
# 16                      Future Me Hates Me
# 17                         Skeptic Goodbye
# 18                    Stranger in the Alps
# ...
