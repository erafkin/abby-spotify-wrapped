# %%
import pandas as pd
artist_genre_df = pd.read_csv("./output/artist_genre_info.csv")
artist_df = pd.read_csv("./output/artist_info.csv")
song_df = pd.read_csv("./output/song_info.csv")
album_counts = pd.read_csv("./output/album_info.csv")

# %%
print(f"you listed to {len(artist_genre_df)} different genres in this time period! Here are the top 15")
artist_genre_df.head(15)
# Out:
# you listed to 276 different genres in this time period! Here are the top 15
#                 genre  count
# 0           indie pop     51
# 1          pov: indie     27
# 2                rock     25
# 3                 pop     25
# 4               alt z     22
# 5          indie rock     21
# 6   singer-songwriter     18
# 7         modern rock     18
# 8             art pop     17
# 9    stomp and holler     16
# 10               folk     15
# 11        chamber pop     15
# 12         indie folk     15
# 13        mellow gold     13
# 14       classic rock     13

# %%
print(f"you listened to {len(artist_df)} artists in this time period!")
print(f"The average popularity of the artists you listen to is {artist_df['popularity'].mean()}. Here are the top 25")
artist_df.head(25)
# Out:
# you listened to 308 artists in this time period!
# The average popularity of the artists you listen to is 61.4448051948052. Here are the top 25
#                      artist  popularity  \
# 0                Noah Kahan          86
# 1                 boygenius          68
# 2                Reneé Rapp          69
# 3             Maggie Rogers          71
# 4            Lizzy McAlpine          75
# 5               girl in red          77
# 6                Lucy Dacus          69
# 7    Florence + The Machine          78
# 8            Brandi Carlile          65
# 9          Lake Street Dive          65
# 10                The Beths          48
# 11             Taylor Swift         100
# 12                Green Day          83
# 13                 La Femme          61
# 14               The Chicks          67
# 15            Chappell Roan          88
# 16               Blondshell          49
# 17            Fleetwood Mac          83
# 18            King Princess          68
# 19             Indigo Girls          54
# 20                  Ratboys          42
# 21               Zach Bryan          90
# 22          Suki Waterhouse          72
# 23  Sammy Rae & The Friends          56
# 24            Billie Eilish          96
#
#                                                genres
# 0             ['pov: indie', 'singer-songwriter pop']
# 1                         ['indie pop', 'pov: indie']
# 2                                           ['alt z']
# 3                                       ['indie pop']
# 4   ['alt z', 'boston folk', 'indie pop', 'singer-...
# 5   ['bedroom pop', 'indie pop', 'norwegian indie'...
# 6                            ['art pop', 'indie pop']
# 7   ['baroque pop', 'modern rock', 'neo mellow', '...
# 8   ['acoustic pop', 'ectofolk', 'folk', 'indie fo...
# 9      ['boston rock', 'indie folk', 'new americana']
# 10  ['auckland indie', 'bubblegrunge', 'indie pop'...
# 11                                            ['pop']
# 12  ['modern rock', 'permanent wave', 'punk', 'rock']
# 13  ['french indie pop', 'french indietronica', 'f...
# 14  ['contemporary country', 'country', 'country d...
# 15                                      ['indie pop']
# 16                      ['bubblegrunge', 'indie pop']
# 17  ['album rock', 'classic rock', 'rock', 'soft r...
# 18                  ['alt z', 'indie pop', 'nyc pop']
# 19  ['ectofolk', 'folk', 'lilith', 'singer-songwri...
# 20    ['bubblegrunge', 'chicago indie', 'indie punk']
# 21                       ['classic oklahoma country']
# 22                                      ['indie pop']
# 23                                        ['nyc pop']
# 24                                 ['art pop', 'pop']

# %%
print(f"you listened to {len(song_df)} songs in this time period!")
print(f"The average popularity of the songs you listen to is {song_df['popularity'].mean()}. Here are the top 25")
song_df.head(50)
# Out:
# you listened to 2700 songs in this time period!
# The average popularity of the songs you listen to is 40.90555555555556. Here are the top 25
#                                              song  popularity  \
# 0                             Born For Loving You          48
# 1                               Not Strong Enough          72
# 2                                       True Blue          62
# 3                                            Free          63
# 4                                   Cool About It          70
# 5               Don't Think Twice, It's All Right          39
# 6                               Dog Days Are Over          73
# 7                                     Y tu te vas          46
# 8                                         Voyager          54
# 9                                 Don't Forget Me          54
# 10                                         Powers          46
# 11                          We Looked Like Giants          33
# 12                         A Change Is Gonna Come          53
# 13                                     Warned You          57
# 14                                   Faith Healer          45
# 15                              Salt In The Wound          55
# 16                                  Leonard Cohen          53
# 17                             Elle ne t'aime pas          62
# 18                                 Don't Know Why          76
# 19                                     Black Hole          48
# 20                                       Caroline          51
# 21                                       Satanist          52
# 22                                New Perspective          72
# 23                              Northern Attitude          75
# 24                                          Maine          53
# 25                                Soak Up The Sun          59
# 26                                Emily I'm Sorry          60
# 27                                Kissing Lessons          47
# 28                            Cowboy Take Me Away          66
# 29  I Remember Everything (feat. Kacey Musgraves)          85
# 30                        Something in the Orange          85
# 31                                     Either Way          36
# 32                 Charm You - Blondshell Version          30
# 33                              Lovers On The Run          28
# 34                     we fell in love in october          85
# 35                                   Good Looking          81
# 36                         Dreams - 2004 Remaster          85
# 37                                            $20          57
# 38                          Letter To An Old Poet          56
# 39                                         Brando          49
# 40                           Please Please Please          87
# 41                        Elvis is in the Freezer          40
# 42                                   Pretty Girls          67
# 43                                  Where or When          63
# 44                            You've Got The Love          63
# 45                                   Stick Season          87
# 46                         1979 - Remastered 2012          77
# 47                                 II MOST WANTED          65
# 48                    Dawns (feat. Maggie Rogers)          76
# 49                                 In The Kitchen          64
#
#                                               artists  \
# 0                                       ['Big Thief']
# 1   ['boygenius', 'Julien Baker', 'Phoebe Bridgers...
# 2   ['boygenius', 'Julien Baker', 'Phoebe Bridgers...
# 3                          ['Florence + The Machine']
# 4   ['boygenius', 'Julien Baker', 'Phoebe Bridgers...
# 5                                    ['Indigo Girls']
# 6                          ['Florence + The Machine']
# 7                                        ['La Femme']
# 8                                       ['boygenius']
# 9                                   ['Maggie Rogers']
# 10                                      ['boygenius']
# 11                              ['Car Seat Headrest']
# 12                                ['Greta Van Fleet']
# 13                                   ['Good Morning']
# 14                                   ['Julien Baker']
# 15  ['boygenius', 'Julien Baker', 'Phoebe Bridgers...
# 16  ['boygenius', 'Julien Baker', 'Phoebe Bridgers...
# 17                                       ['La Femme']
# 18                                    ['Norah Jones']
# 19                                      ['boygenius']
# 20           ['Baby Rose', 'BADBADNOTGOOD', 'Mereba']
# 21  ['boygenius', 'Julien Baker', 'Phoebe Bridgers...
# 22                                     ['Noah Kahan']
# 23                                     ['Noah Kahan']
# 24                                   ['hey, nothing']
# 25                                    ['Sheryl Crow']
# 26  ['boygenius', 'Julien Baker', 'Phoebe Bridgers...
# 27                                     ['Lucy Dacus']
# 28                                     ['The Chicks']
# 29                  ['Zach Bryan', 'Kacey Musgraves']
# 30                                     ['Zach Bryan']
# 31                                     ['Odie Leigh']
# 32                            ['Blondshell', 'Samia']
# 33                           ['The Plastic Cherries']
# 34                                    ['girl in red']
# 35                                ['Suki Waterhouse']
# 36                                  ['Fleetwood Mac']
# 37  ['boygenius', 'Julien Baker', 'Phoebe Bridgers...
# 38  ['boygenius', 'Julien Baker', 'Phoebe Bridgers...
# 39                                     ['Lucy Dacus']
# 40                              ['Sabrina Carpenter']
# 41                                        ['Ratboys']
# 42                                     ['Reneé Rapp']
# 43                                         ['Laufey']
# 44                         ['Florence + The Machine']
# 45                                     ['Noah Kahan']
# 46                          ['The Smashing Pumpkins']
# 47                         ['Beyoncé', 'Miley Cyrus']
# 48                    ['Zach Bryan', 'Maggie Rogers']
# 49                                     ['Reneé Rapp']
#
#                                                 album
# 0                Vampire Empire / Born For Loving You
# 1                                          the record
# 2                                          the record
# 3                                         Dance Fever
# 4                                          the record
# 5                    Staring Down The Brilliant Dream
# 6                              Lungs (Deluxe Edition)
# 7                                       Teatro Lúcido
# 8                                            the rest
# 9                                     Don't Forget Me
# 10                                           the rest
# 11           We Looked Like Giants / Brand New Colony
# 12                                     From The Fires
# 13                                          Shawcross
# 14                                   Little Oblivions
# 15                                          boygenius
# 16                                         the record
# 17                                            Mystère
# 18           Come Away With Me (Super Deluxe Edition)
# 19                                           the rest
# 20                                          Slow Burn
# 21                                         the record
# 22                                       Stick Season
# 23                                       Stick Season
# 24                                     Maine/The Sink
# 25                                       C'Mon, C'Mon
# 26                                         the record
# 27                                    Kissing Lessons
# 28                                                Fly
# 29                                         Zach Bryan
# 30                            Something in the Orange
# 31                                         Either Way
# 32                     Charm You (Blondshell Version)
# 33                   The Plastic Cherries On The Moon
# 34  we fell in love in october / October Passed Me By
# 35                                       Good Looking
# 36                             Rumours (Super Deluxe)
# 37                                         the record
# 38                                         the record
# 39                                         Home Video
# 40                               Please Please Please
# 41                                                 GN
# 42                                         Snow Angel
# 43                                      Where or When
# 44                             Lungs (Deluxe Edition)
# 45                                       Stick Season
# 46  Mellon Collie And The Infinite Sadness (Deluxe...
# 47                                      COWBOY CARTER
# 48                        Dawns (feat. Maggie Rogers)
# 49                             Everything To Everyone

# %%
print(f"you listened to {len(album_counts)} different albums this year!")
print("here are the top 20")
album_counts.head(20)
# Out:
# you listened to 1701 different albums this year!
# here are the top 20
#                                               artists  count
# 0                                       ['Big Thief']      2
# 1   ['boygenius', 'Julien Baker', 'Phoebe Bridgers...     17
# 2                          ['Florence + The Machine']      7
# 3                                    ['Indigo Girls']      1
# 4                          ['Florence + The Machine']      3
# 5                                        ['La Femme']      6
# 6                                       ['boygenius']      4
# 7                                   ['Maggie Rogers']     10
# 8   ['Car Seat Headrest'], ['The Beths', 'Pickle D...      2
# 9                                 ['Greta Van Fleet']      1
# 10                                   ['Good Morning']      2
# 11                                   ['Julien Baker']      6
# 12  ['boygenius', 'Julien Baker', 'Phoebe Bridgers...      6
# 13                                       ['La Femme']      6
# 14                                    ['Norah Jones']      2
# 15           ['Baby Rose', 'BADBADNOTGOOD', 'Mereba']      1
# 16                                     ['Noah Kahan']     14
# 17                                   ['hey, nothing']      2
# 18                                    ['Sheryl Crow']      1
# 19                                     ['Lucy Dacus']      1
