# %%
import pandas as pd
artist_genre_df = pd.read_csv("./output/jessica_artist_genre_info.csv")
artist_df = pd.read_csv("./output/jessica_artist_info.csv")
song_df = pd.read_csv("./output/jessica_song_info.csv")
album_counts = pd.read_csv("./output/jessica_album_info.csv")

# %%
print(f"you listed to {len(artist_genre_df)} different genres in this time period! Here are the top 15")
artist_genre_df.head(15)
# Out:
# you listed to 182 different genres in this time period! Here are the top 15
#                       genre  count
# 0                       pop    103
# 1                     alt z     39
# 2                 dance pop     29
# 3                    uk pop     18
# 4                 indie pop     17
# 5               modern rock     17
# 6                pov: indie     16
# 7     singer-songwriter pop     15
# 8                      rock     11
# 9   gen z singer-songwriter     10
# 10             canadian pop      9
# 11             indietronica      9
# 12               indie rock      8
# 13                      edm      8
# 14                  art pop      8

# %%
print(f"you listened to {len(artist_df)} artists in this time period!")
print(f"The average popularity of the artists you listen to is {artist_df['popularity'].mean()}. Here are the top 25")
artist_df.head(25)
# Out:
# you listened to 265 artists in this time period!
# The average popularity of the artists you listen to is 70.89056603773585. Here are the top 25
#                 artist  popularity  \
# 0         Taylor Swift         100
# 1        Gracie Abrams          90
# 2           Noah Kahan          86
# 3       Chelsea Cutler          68
# 4       Olivia Rodrigo          88
# 5        Maisie Peters          64
# 6    Sabrina Carpenter          94
# 7        One Direction          89
# 8           Conan Gray          81
# 9                Griff          69
# 10          Reneé Rapp          69
# 11       Maggie Rogers          71
# 12          Tate McRae          86
# 13          Noah Cyrus          75
# 14                Lauv          77
# 15       Lennon Stella          62
# 16        The National          67
# 17        Harry Styles          85
# 18               Lorde          78
# 19               Adele          87
# 20     Phoebe Bridgers          80
# 21           girlhouse          37
# 22  Charlotte Lawrence          57
# 23              Gatlin          49
# 24          Ed Sheeran          90
#
#                                                genres
# 0                                             ['pop']
# 1                                           ['alt z']
# 2             ['pov: indie', 'singer-songwriter pop']
# 3                                           ['alt z']
# 4                                             ['pop']
# 5                                 ['alt z', 'uk pop']
# 6                                             ['pop']
# 7   ['boy band', 'pop', 'post-teen pop', 'talent s...
# 8                ['bedroom pop', 'pop', 'pov: indie']
# 9                                 ['alt z', 'uk pop']
# 10                                          ['alt z']
# 11                                      ['indie pop']
# 12                                            ['pop']
# 13                                   ['alt z', 'pop']
# 14                                            ['pop']
# 15                ['alt z', 'canadian pop', 'uk pop']
# 16  ['chamber pop', 'indie folk', 'indie rock', 'i...
# 17                                            ['pop']
# 18       ['art pop', 'metropopolis', 'nz pop', 'pop']
# 19      ['british soul', 'pop', 'pop soul', 'uk pop']
# 20            ['indie pop', 'la indie', 'pov: indie']
# 21                                      ['indie pop']
# 22                                          ['alt z']
# 23                         ['modern alternative pop']
# 24         ['pop', 'singer-songwriter pop', 'uk pop']

# %%
print(f"you listened to {len(song_df)} songs in this time period!")
print(f"The average popularity of the songs you listen to is {song_df['popularity'].mean()}. Here are the top 25")
song_df.head(25)
# Out:
# you listened to 3939 songs in this time period!
# The average popularity of the songs you listen to is 52.29119065752729. Here are the top 25
#                                                  song  popularity  \
# 0         "Slut!" (Taylor's Version) (From The Vault)          74
# 1   Now That We Don't Talk (Taylor's Version) (Fro...          75
# 2   Is It Over Now? (Taylor's Version) (From The V...          75
# 3    Say Don't Go (Taylor's Version) (From The Vault)          70
# 4   Suburban Legends (Taylor's Version) (From The ...          65
# 5                                      Hits Different          70
# 6                             You're On Your Own, Kid          76
# 7                                       The Black Dog          74
# 8                       Fortnight (feat. Post Malone)          75
# 9                My Boy Only Breaks His Favorite Toys          74
# 10                                         Two people          56
# 11                         I Look in People's Windows          69
# 12                                     So High School          76
# 13                                        Getaway Car          76
# 14                                     Guilty as Sin?          76
# 15                                    How Did It End?          75
# 16                                              Peter          72
# 17                                           Down Bad          74
# 18                                          Difficult          61
# 19        Snow On The Beach (feat. More Lana Del Rey)          70
# 20                    The Smallest Man Who Ever Lived          74
# 21                                         Mess It Up          77
# 22                      The Tortured Poets Department          72
# 23                                    So Long, London          74
# 24                              Fresh Out The Slammer          71
#
#                              artists  \
# 0                   ['Taylor Swift']
# 1                   ['Taylor Swift']
# 2                   ['Taylor Swift']
# 3                   ['Taylor Swift']
# 4                   ['Taylor Swift']
# 5                   ['Taylor Swift']
# 6                   ['Taylor Swift']
# 7                   ['Taylor Swift']
# 8    ['Taylor Swift', 'Post Malone']
# 9                   ['Taylor Swift']
# 10                 ['Gracie Abrams']
# 11                  ['Taylor Swift']
# 12                  ['Taylor Swift']
# 13                  ['Taylor Swift']
# 14                  ['Taylor Swift']
# 15                  ['Taylor Swift']
# 16                  ['Taylor Swift']
# 17                  ['Taylor Swift']
# 18                 ['Gracie Abrams']
# 19  ['Taylor Swift', 'Lana Del Rey']
# 20                  ['Taylor Swift']
# 21                 ['Gracie Abrams']
# 22                  ['Taylor Swift']
# 23                  ['Taylor Swift']
# 24                  ['Taylor Swift']
#
#                                            album
# 0                        1989 (Taylor's Version)
# 1                        1989 (Taylor's Version)
# 2                        1989 (Taylor's Version)
# 3                        1989 (Taylor's Version)
# 4                        1989 (Taylor's Version)
# 5               Midnights (The Til Dawn Edition)
# 6                                      Midnights
# 7   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 8   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 9   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 10                        Good Riddance (Deluxe)
# 11  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 12  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 13                                    reputation
# 14  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 15  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 16  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 17  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 18                        Good Riddance (Deluxe)
# 19              Midnights (The Til Dawn Edition)
# 20  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 21                                    Mess It Up
# 22  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 23  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# 24  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY

# %%
print(f"you listened to {len(album_counts)} different albums this year!")
print("here are the top 20")
album_counts.head(20)
# Out:
# you listened to 2382 different albums this year!
# here are the top 20
#                                               artists  count
# 0                                    ['Taylor Swift']     21
# 1   ['Taylor Swift'], ['Taylor Swift', 'Lana Del R...     28
# 2   ['Taylor Swift'], ['Taylor Swift', 'Lana Del R...     14
# 3   ['Taylor Swift'], ['Taylor Swift', 'Post Malon...     32
# 4                                   ['Gracie Abrams']     20
# 5   ['Taylor Swift'], ['Taylor Swift', 'Ed Sheeran...     15
# 6                                   ['Gracie Abrams']      1
# 7   ['Taylor Swift'], ['Taylor Swift', 'The Chicks...     18
# 8   ['Taylor Swift'], ['Taylor Swift', 'Keith Urba...     26
# 9                                    ['Taylor Swift']      1
# 10     ['Taylor Swift'], ['Taylor Swift', 'Bon Iver']     16
# 11                                   ['Taylor Swift']      1
# 12  ['Taylor Swift'], ['Taylor Swift', 'Chris Stap...     39
# 13  ['Taylor Swift'], ['Taylor Swift', 'The Nation...     24
# 14  ['Taylor Swift'], ['Taylor Swift', 'Fall Out B...     22
# 15                                   ['Taylor Swift']     20
# 16                                  ['Gracie Abrams']     13
# 17  ['Taylor Swift'], ['Taylor Swift', 'HAIM'], ['...     15
# 18                                  ['Gracie Abrams']     12
# 19                                 ['Olivia Rodrigo']      5
