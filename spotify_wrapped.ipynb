# %%
import pandas as pd
folder="./output"
artist_genre_df = pd.read_csv(f"{folder}/artist_genre_info.csv")
artist_df = pd.read_csv(f"{folder}/artist_info.csv")
song_df = pd.read_csv(f"{folder}/song_info.csv")
album_counts = pd.read_csv(f"{folder}/album_info.csv")

# %%
print(f"you listed to {len(artist_genre_df)} different genres in this time period! Here are the top 15")
artist_genre_df.head(15)
# Out:
# you listed to 73 different genres in this time period! Here are the top 15
#                 genre  count
# 0                folk     16
# 1          indie folk     14
# 2         baroque pop     10
# 3               indie     10
# 4            folk pop      8
# 5   singer-songwriter      7
# 6           dream pop      6
# 7           americana      6
# 8         alt country      6
# 9           folk rock      5
# 10          indie pop      5
# 11         indie rock      5
# 12         jangle pop      5
# 13        bedroom pop      5
# 14       classic rock      5

# %%
print(f"you listened to {len(artist_df)} artists in this time period!")
print(f"The average popularity of the artists you listen to is {artist_df['popularity'].mean()}. Here are the top 25")
artist_df.head(25)
# Out:
# you listened to 217 artists in this time period!
# The average popularity of the artists you listen to is 60.29032258064516. Here are the top 25
#                     artist  popularity                              genres
# 0                The Beths          53         ['indie rock', 'power pop']
# 1                You Won't          22                                  []
# 2                boygenius          64                                  []
# 3          Vampire Weekend          63            ['indie', 'baroque pop']
# 4                Big Thief          70                                  []
# 5                     HAIM          65                                  []
# 6   Florence + The Machine          80                     ['baroque pop']
# 7                Wednesday          56                     ['alt country']
# 8            The Fratellis          62                                  []
# 9               Lucy Dacus          66                                  []
# 10              Noah Kahan          84                                  []
# 11           The Lumineers          77          ['folk pop', 'indie folk']
# 12                 Ratboys          41                                  []
# 13         The Cranberries          77                                  []
# 14            Julien Baker          64                    ['ambient folk']
# 15         The Paper Kites          68                      ['indie folk']
# 16             Olivia Dean          91                        ['pop soul']
# 17           Orla Gartland          48                       ['indie pop']
# 18      Japanese Breakfast          59                                  []
# 19                 Foxygen          41  ['baroque pop', 'neo-psychedelic']
# 20                     Djo          76                                  []
# 21                 Wet Leg          64             ['indie rock', 'indie']
# 22            hey, nothing          53                     ['midwest emo']
# 23                 Snocaps          52                                  []
# 24         Adrianne Lenker          74                                  []

# %%
print(f"you listened to {len(song_df)} songs in this time period!")
print(f"The average popularity of the songs you listen to is {song_df['popularity'].mean()}. Here are the top 25")
song_df.head(25)
# Out:
# you listened to 2257 songs in this time period!
# The average popularity of the songs you listen to is 49.30660168365086. Here are the top 25
#                                        song  popularity  \
# 0                    Rainy Days And Mondays          64
# 1                    Something on Your Mind          33
# 2                 A Feeling That Never Came          36
# 3              I Told You That I Was Afraid          33
# 4              The Experiment - Bonus Track          28
# 5   I Told You That I Was Afraid - Acoustic          17
# 6                                     Fryer          15
# 7                              The Hopefuls          27
# 8                              Once A Bunch          41
# 9                    Weird Fishes / Arpeggi          79
# 10                               Mosquitoes          46
# 11                           Stephanie Says          54
# 12                          Elderberry Wine          60
# 13                                Henrietta          58
# 14                                   Dreams          83
# 15                            San Francisco          50
# 16                                  Paprika          53
# 17                           No One Noticed          90
# 18                                 Caroline          53
# 19                               Bike Dream          38
# 20                         Simulation Swarm          70
# 21                              Hannah Hunt          12
# 22                             Beta Paradox          30
# 23                           No Destruction          36
# 24                                 Punisher          64
#
#                        artists  \
# 0               ['Carpenters']
# 1             ['Karen Dalton']
# 2            ['First Aid Kit']
# 3                ['The Beths']
# 4                    ['Daffo']
# 5                ['The Beths']
# 6                ["You Won't"]
# 7             ['Adam Melchor']
# 8          ['Adrianne Lenker']
# 9                ['Radiohead']
# 10               ['The Beths']
# 11  ['The Velvet Underground']
# 12               ['Wednesday']
# 13           ['The Fratellis']
# 14         ['The Cranberries']
# 15                 ['Foxygen']
# 16      ['Japanese Breakfast']
# 17              ['The Marías']
# 18              ['Arlo Parks']
# 19                  ['Rostam']
# 20               ['Big Thief']
# 21         ['Vampire Weekend']
# 22                   ['yeemz']
# 23                 ['Foxygen']
# 24         ['Phoebe Bridgers']
#
#                                                 album
# 0                                          Carpenters
# 1                                      In My Own Time
# 2                                            Palomino
# 3                             Expert In A Dying Field
# 4                                                Pest
# 5                    Expert In A Dying Field (Deluxe)
# 6                                     Skeptic Goodbye
# 7                                 The Diary of Living
# 8                                        Once A Bunch
# 9                                         In Rainbows
# 10                            Straight Line Was A Lie
# 11                                                 VU
# 12                                             Bleeds
# 13                                     Costello Music
# 14       Everybody Else Is Doing It, So Why Can't We?
# 15  We Are the 21st Century Ambassadors of Peace &...
# 16                                            Jubilee
# 17                                          Submarine
# 18                              Collapsed In Sunbeams
# 19                                         Half-Light
# 20          Dragon New Warm Mountain I Believe In You
# 21                        Modern Vampires of the City
# 22                                     Blame The Gods
# 23  We Are the 21st Century Ambassadors of Peace &...
# 24                                           Punisher

# %%
print(f"you listened to {len(album_counts)} different albums!")
print("here are the top 20")
album_counts.head(20)
# Out:
# you listened to 1271 different albums!
# here are the top 20
#                                                 album  \
# 0                                          Carpenters
# 1                                      In My Own Time
# 2                                            Palomino
# 3                             Expert In A Dying Field
# 4                                                Pest
# 5                    Expert In A Dying Field (Deluxe)
# 6                                     Skeptic Goodbye
# 7                                 The Diary of Living
# 8                                        Once A Bunch
# 9                                         In Rainbows
# 10                            Straight Line Was A Lie
# 11                                                 VU
# 12                                             Bleeds
# 13                                     Costello Music
# 14       Everybody Else Is Doing It, So Why Can't We?
# 15  We Are the 21st Century Ambassadors of Peace &...
# 16                                            Jubilee
# 17                                          Submarine
# 18                              Collapsed In Sunbeams
# 19                                         Half-Light
#
#                                               artists  count
# 0                                      ['Carpenters']      1
# 1                                    ['Karen Dalton']      2
# 2                                   ['First Aid Kit']      2
# 3                                       ['The Beths']     12
# 4                                           ['Daffo']      2
# 5                                       ['The Beths']      4
# 6                                       ["You Won't"]     12
# 7   ['Adam Melchor'], ['Adam Melchor', 'Mt. Joy'],...      7
# 8                                 ['Adrianne Lenker']      1
# 9                                       ['Radiohead']      2
# 10                                      ['The Beths']     10
# 11                         ['The Velvet Underground']      1
# 12       ['Wednesday'], ['Wednesday', 'Advance Base']     12
# 13                                  ['The Fratellis']     13
# 14                                ['The Cranberries']      3
# 15                                        ['Foxygen']      8
# 16                             ['Japanese Breakfast']     10
# 17                                     ['The Marías']      2
# 18                                     ['Arlo Parks']      1
# 19                                         ['Rostam']      1
